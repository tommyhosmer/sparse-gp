# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('trainingdata.csv')
latent = pd.read_csv('latentfunction.csv')
plt.scatter(df['X'], df['Y'],s=20,marker='+')
plt.plot(latent['X'],latent['Y'])
plt.show()
